# %% [markdown]
# # Visualizing Earnings Based On College Majors
#
# ### Do students in more popular majors make more money?
# #### Using scatter plots
# ### How many majors are predominantly male? Predominantly female?
# #### Using histograms
# ### Which category of majors have the most students?
# #### Using bar plots

# %% [markdown]
# ### Columns description
# * Rank - Rank by median earnings (the dataset is ordered by this column).
# * Major_code - Major code.
# * Major - Major description.
# * Major_category - Category of major.
# * Total - Total number of people with major.
# * Sample_size - Sample size (unweighted) of full-time.
# * Men - Male graduates.
# * Women - Female graduates.
# * ShareWomen - Women as share of total.
# * Employed - Number employed.
# * Median - Median salary of full-time, year-round workers.
# * Low_wage_jobs - Number in low-wage service jobs.
# * Full_time - Number employed 35 hours or more.
# * Part_time - Number employed less than 35 hours.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# Low_wage_jobs                             193
# Name: 0, dtype: object

# %%
recent_grads.head(2)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# 0      ...              270                  1207          37
# 1      ...              170                   388          85
# 2      ...              133                   340          16
# 3      ...              150                   692          40
# 4      ...             5180                 16697        1672
#
#    Unemployment_rate  Median  P25th   P75th  College_jobs  Non_college_jobs  \
# 0           0.018381  110000  95000  125000          1534               364
# 1           0.117241   75000  55000   90000           350               257
# 2           0.024096   73000  50000  105000           456               176
# 3           0.050125   70000  43000   80000           529               102
# 4           0.061098   65000  50000   75000         18314              4440
#
#    Low_wage_jobs
# 0            193
# 1             50
# 2              0
# 3              0
# 4            972
#
# [5 rows x 21 columns]

# %%
recent_grads.tail(2)
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# 169      ...              572                  1211         148
# 170      ...              648                  1293         368
# 171      ...              965                  2738         214
# 172      ...              237                   410          87
#
#      Unemployment_rate  Median  P25th  P75th  College_jobs  Non_college_jobs  \
# 168           0.046320   26000  20000  39000          2771              2947
# 169           0.065112   25000  24000  34000          1488               615
# 170           0.149048   25000  25000  40000           986               870
# 171           0.053621   23400  19200  26000          2403              1245
# 172           0.104946   22000  20000  22000           288               338
#
#      Low_wage_jobs
# 168            743
# 169             82
# 170            622
# 171            308
# 172            192
#
# [5 rows x 21 columns]

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# std      0.231205   618.361022   50675.002241   42869.655092   14648.179473
# min      0.000000     2.000000       0.000000     111.000000       0.000000
# 25%      0.336026    39.000000    3608.000000    3154.000000    1030.000000
# 50%      0.534024   130.000000   11797.000000   10048.000000    3299.000000
# 75%      0.703299   338.000000   31433.000000   25147.000000    9948.000000
# max      0.968954  4212.000000  307933.000000  251540.000000  115172.000000
#
#        Full_time_year_round    Unemployed  Unemployment_rate         Median  \
# count            173.000000    173.000000         173.000000     173.000000
# mean           19694.427746   2416.329480           0.068191   40151.445087
# std            33160.941514   4112.803148           0.030331   11470.181802
# min              111.000000      0.000000           0.000000   22000.000000
# 25%             2453.000000    304.000000           0.050306   33000.000000
# 50%             7413.000000    893.000000           0.067961   36000.000000
# 75%            16891.000000   2393.000000           0.087557   45000.000000
# max           199897.000000  28169.000000           0.177226  110000.000000
#
#               P25th          P75th   College_jobs  Non_college_jobs  \
# count    173.000000     173.000000     173.000000        173.000000
# mean   29501.445087   51494.219653   12322.635838      13284.497110
# std     9166.005235   14906.279740   21299.868863      23789.655363
# min    18500.000000   22000.000000       0.000000          0.000000
# 25%    24000.000000   42000.000000    1675.000000       1591.000000
# 50%    27000.000000   47000.000000    4390.000000       4595.000000
# 75%    33000.000000   60000.000000   14444.000000      11783.000000
# max    95000.000000  125000.000000  151643.000000     148395.000000
#
#        Low_wage_jobs
# count     173.000000
# mean     3859.017341
# std      6944.998579
# min         0.000000
# 25%       340.000000
# 50%      1231.000000
# 75%      3466.000000
# max     48207.000000

# %%
raw_data_count = recent_grads.shape
print(raw_data_count)
# Out:
# (173, 21)

# %%
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape
print(cleaned_data_count)
# Out:
# (172, 21)

# %%
ax0 = recent_grads.plot(x='Sample_size', y='Total', kind='scatter')
ax0.set_title('Total vs. Sample_size')

ax1 = recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
ax1.set_title('Median vs. Sample_size')
ax2 = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
ax2.set_title('Unemployed Rate vs. Sample_size')
ax3 = recent_grads.plot(x='Full_time', y='Median', kind='scatter')
ax3.set_title('Median vs. Full Time')

# %%
ax4 = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')
ax4.set_title('Unemployed Rate vs. Women Share')
ax5 = recent_grads.plot(x='Men', y='Median', kind='scatter')
ax5.set_title('Median vs. Men')
ax6 = recent_grads.plot(x='Women', y='Median', kind='scatter')
ax6.set_title('Median vs. Women')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Compute the correlation matrix
corr = recent.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### Use the plots to explore the following questions:
# #### Do students in more popular majors make more money?
# ##### No, the plot between sample size and median does not show positive correlation. As sample size increases or more people are taking in the major, the salary median does not increase, rather, we see a downward trend here.
# #### Do students that majored in subjects that were majority female make more money?
# ##### No, the scatter plot between median salary and women count also does not show positive corellation. Rather, we see downward trend/negative correlation.
# #### Is there any link between the number of full-time employees and median salary?
# ##### Yes, less salary has higher count of full time employees (negative correlation)

# %%
fig = plt.figure(figsize = (30,200))
cols = ['Sample_size','Median','Employed','Full_time','ShareWomen','Unemployment_rate','Men',
'Women']

for i in range(0,8):
    ax = fig.add_subplot(8,1,i+1)
    ax.hist(recent_grads[cols[i]], bins=25, range=(0,recent_grads[cols[i]].max()))
    ax.set_title("Distribution of "+ cols[i])

# %%
recent_grads['Median'].hist(bins=25, range=(0,110000))

# %%
recent_grads['Employed'].hist(bins=40, range=(-5,32000))

# %%
recent_grads['Full_time'].hist(bins=30, range=(-5,261000))

# %%
recent_grads['ShareWomen'].hist(bins=25, range=(0,1.2))

# %%
recent_grads['Unemployment_rate'].hist(bins=25, range=(0,.2))

# %%
recent_grads['Men'].hist(bins=25, range=(0,27000))

# %%
recent_grads['Women'].hist(bins=25, range=(0,25000))

# %% [markdown]
# #### What percent of majors are predominantly male? Predominantly female?
# ##### only about 10% of majors are predominantly male or female
# #### What's the most common median salary range?
# ##### approximately USD30000-35000

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size','Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f84a23d6b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84a22d7160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f84a22a0320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84a2257898>]],
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f84a222fba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84a20fa278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84a20c2c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f84a207d9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84a2048a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84a20d3908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f84a1fbecf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84a1fcd5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84a1f4c400>]],
#       dtype=object)

# %% [markdown]
# #### Same observation as before

# %%
scatter_matrix(recent_grads[['Women','Men','Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f84a1e52e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84a1dcb6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84a1d94f98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f84a1d4fc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84a1d18e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84a1ce0320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f84a1caaa20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84a1beb160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f84a1bb54a8>]],
#       dtype=object)

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend = False)
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen', legend = False)

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate', legend = False)
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate', legend = False)

# %% [markdown]
# ## Comparing the number of men with the number of women in each category of majors.

# %%
category_uniq = recent_grads["Major_category"].unique()
cat_women = {}
cat_men = {}
for cat in category_uniq:
    boolcat = recent_grads['Major_category'] == cat
    cat_w = recent_grads[boolcat]['Women']
    cat_m = recent_grads[boolcat]['Men']
    cat_women[cat] = cat_w.sum()
    cat_men[cat] = cat_m.sum()

df_cat= pd.DataFrame({'Women':cat_women, 'Men': cat_men})


df_cat.plot.bar()

# %%
def maj_cat_mean(s):
    category_uniq = recent_grads["Major_category"].unique()
    cat_dict = {}
    for cat in category_uniq:
        boolcat = recent_grads['Major_category'] == cat
        cat_1 = recent_grads[boolcat][s]
        cat_dict[cat] = cat_1.mean()
    return cat_dict
def maj_cat_max(s):
    category_uniq = recent_grads["Major_category"].unique()
    cat_dict = {}
    for cat in category_uniq:
        boolcat = recent_grads['Major_category'] == cat
        cat_1 = recent_grads[boolcat][s]
        cat_dict[cat] = cat_1.max()
    return cat_dict

# %%
unemp_dict = maj_cat_mean('Unemployment_rate')
df_cat_unem= pd.DataFrame({'Unemployment rate':unemp_dict})
df_cat_unem = df_cat_unem.sort_values(by='Unemployment rate')
df_cat_unem.plot.bar(title = 'Average Unemployment Rating per Major Category', legend = False)

# %%
unemp_dict = maj_cat_max('Unemployment_rate')
df_cat_unem= pd.DataFrame({'Unemployment rate':unemp_dict})
df_cat_unem = df_cat_unem.sort_values(by='Unemployment rate')
df_cat_unem.plot.bar(title = 'Max Unemployment Rating per Major Category', legend = False)

# %%
eng_cat = recent_grads[recent_grads['Major_category'] == 'Engineering'].sort_values(by='Unemployment_rate')
eng_cat_major = eng_cat[eng_cat['Unemployment_rate']==eng_cat['Unemployment_rate'].max()]
eng_cat.plot.bar(x='Major', y='Unemployment_rate', legend = False)
# Out:
# 0.06333387717241379

# %%
average = str(eng_cat['Unemployment_rate'].mean())
print('Engineering Average unemployment rate: ' + average )
print('Engineering major with highest unemployment rate: '+ str(eng_cat_major['Major']))
# Out:
# Engineering Average unemployment rate: 0.06333387717241379
# Engineering major with highest unemployment rate: 5    NUCLEAR ENGINEERING
# Name: Major, dtype: object

# %%
recent_grads.columns[7:-5]
# Out:
# Index(['ShareWomen', 'Sample_size', 'Employed', 'Full_time', 'Part_time',
#        'Full_time_year_round', 'Unemployed', 'Unemployment_rate', 'Median'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def plot_null_correlations(df):
    # create a correlation matrix only for columns with at least
    # one missing value
    cols_with_missing_vals = df.columns[df.isnull().sum() > 0]
    missing_corr = df[cols_with_missing_vals].isnull().corr()
    
    # create a triangular mask to avoid repeated values and make
    # the plot easier to read
    missing_corr = missing_corr.iloc[1:, :-1]
    mask = np.triu(np.ones_like(missing_corr), k=1)
    
    # plot a heatmap of the values
    plt.figure(figsize=(20,14))
    ax = sns.heatmap(missing_corr, vmin=-1, vmax=1, cbar=False,
                     cmap='RdBu', mask=mask, annot=True)
    
    # format the text in the plot to make it easier to read
    for text in ax.texts:
        t = float(text.get_text())
        if -0.05 < t < 0.01:
            text.set_text('')
        else:
            text.set_text(round(t, 2))
        text.set_fontsize('x-large')
    plt.xticks(rotation=90, size='x-large')
    plt.yticks(rotation=0, size='x-large')
    plt.show()
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/matplotlib/axes/_base.py:3045: UserWarning:
#
# Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0, top=0
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/matplotlib/axes/_base.py:2787: UserWarning:
#
# Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0, right=0
